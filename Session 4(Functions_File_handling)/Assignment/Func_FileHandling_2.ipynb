# %% [markdown]
# # AssignmentNo_6

# %% [markdown]
# ### Q1.Create a module named "WordCount.py" that contains function(s) to calculate the number of characters and words in a given sentence.
# ### By importing the above module write a program which asks user to input a sentence and then displays the number of characters and words in the sentence. e.g. if a user inputs "Hello World", the output should be No. of characters =11(including spaces and special characters) and No. of words= 2.

# %% [markdown]
# ### Q2. Write a program to implement/create the following package structure using the python directory and file commands such that load.py when imported in the main program should print "Loading file...." and similarly display.py when imported should print "Displaying output....".
# ![image.jpeg](attachment:image.jpeg)
# <br/>
# <span style="font-size:1.2em">
# Hint: <br/>
#     1. We can make use of in-built function open() in write mode to create an empty file if it is not present and then use write() function to write into that file. <br/>
#     2. __init__.py files can be kept empty if there is no initialization operation you want to perform when importing a module.
# </span>
